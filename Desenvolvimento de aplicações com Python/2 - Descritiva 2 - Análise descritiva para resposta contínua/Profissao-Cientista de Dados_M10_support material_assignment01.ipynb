# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
#Leitura csv e drop colunas não úteis
previsao_renda = pd.read_csv('previsao_de_renda.csv')
previsao_renda = previsao_renda.drop(['Unnamed: 0', 'index'], axis = 1)
previsao_renda.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# ...

# %%
#Verifica as caracteristicas do DataFrame
previsao_renda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_ref               15000 non-null  object
#  1   sexo                   15000 non-null  object
#  2   posse_de_veiculo       15000 non-null  bool
#  3   posse_de_imovel        15000 non-null  bool
#  4   qtd_filhos             15000 non-null  int64
#  5   tipo_renda             15000 non-null  object
#  6   educacao               15000 non-null  object
#  7   estado_civil           15000 non-null  object
#  8   tipo_residencia        15000 non-null  object
#  9   idade                  15000 non-null  int64
#  10  tempo_emprego          12466 non-null  float64
#  11  qt_pessoas_residencia  15000 non-null  float64
#  12  mau                    15000 non-null  bool
#  13  renda                  15000 non-null  float64
# ...

# %%
#Tabela de metadados para facilitar visualização
metadados = pd.DataFrame({'dtypes': previsao_renda.dtypes})
metadados['missing'] = previsao_renda.isna().sum()
metadados['valores_unicos'] = previsao_renda.nunique()

metadados
# Out:
#                         dtypes  missing  valores_unicos
# data_ref                object        0              15
# sexo                    object        0               2
# posse_de_veiculo          bool        0               2
# posse_de_imovel           bool        0               2
# qtd_filhos               int64        0               8
# tipo_renda              object        0               5
# educacao                object        0               5
# estado_civil            object        0               5
# tipo_residencia         object        0               6
# idade                    int64        0              47
# tempo_emprego          float64     2534            2571
# qt_pessoas_residencia  float64        0               9
# mau                       bool        0               2
# renda                  float64        0            9759

# %%
#Drop dos missing values
previsao_renda_semna = previsao_renda.dropna().reset_index(drop=True)
previsao_renda_semna.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# 0       3.575342                    3.0  False  3369.24
# ...

# %%
#Seleciona somente variáveis numéricas quantitativas
var_quantitativo = list(previsao_renda_semna.select_dtypes('number'))
previsao_renda_semna[var_quantitativo].head()
# Out:
#    qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda
# 0           1     36       3.575342                    3.0  3369.24
# 1           0     42       0.860274                    2.0  6096.14
# 2           2     31       8.065753                    4.0  5658.98
# 3           0     50       1.208219                    2.0  7246.69
# 4           0     52      13.873973                    2.0  4017.37

# %%
#Estrutura de correlação entre as variáveis selecionadas
previsao_renda_semna[var_quantitativo].corr()
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.289012      -0.074250
# idade                   -0.289012  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.908703 -0.257281      -0.065748
# renda                   -0.016189  0.151364       0.394235
#
#                        qt_pessoas_residencia     renda
# qtd_filhos                          0.908703 -0.016189
# idade                              -0.257281  0.151364
# tempo_emprego                      -0.065748  0.394235
# qt_pessoas_residencia               1.000000 -0.004865
# renda                              -0.004865  1.000000

# %%
#Estrutura de correlação com variáveis fortemente relacionadas
previsao_renda_semna[['qtd_filhos','qt_pessoas_residencia']].corr()
# Out:
#                        qtd_filhos  qt_pessoas_residencia
# qtd_filhos               1.000000               0.908703
# qt_pessoas_residencia    0.908703               1.000000

# %% [markdown]
# Podemos verificar que há uma alta correlação entre as variáveis qtd_filhos e qt_pessoas_residencia, sendo que a variável qt_pessoas_residencia pode ser falcilmente explicada pelas demais variáveis.

# %%
#Matriz de dispersão para as variáveis numéricas
var_quantitativo = list(previsao_renda_semna.select_dtypes('number'))

var_quantitativo.append('mau')

sns.pairplot(previsao_renda_semna[var_quantitativo].sample(n=10000), hue='mau')

# %%
#Clustermap da estrutura de correlação
var_quantitativo = list(previsao_renda_semna.select_dtypes('number'))

color = sns.diverging_palette(h_neg=125, 
                              h_pos=600,
                              as_cmap=True,
                              sep = 40, 
                              center = 'light')

sns.clustermap(previsao_renda_semna[var_quantitativo].corr(), 
               figsize=(8, 8), 
               center = 0,
               cmap=color)

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
#Gráfico scatterplot da renda pelo tempo de emprego
sns.scatterplot(data=previsao_renda_semna[var_quantitativo].sample(n=500),
                x='tempo_emprego',
                y='renda')
# Out:
# <Axes: xlabel='tempo_emprego', ylabel='renda'>

# %%
#Gráfico regplot da renda pelo tempo de emprego
sns.regplot(data=previsao_renda_semna[var_quantitativo].sample(n=500),
            x='tempo_emprego',
            y='renda')
# Out:
# <Axes: xlabel='tempo_emprego', ylabel='renda'>

# %% [markdown]
# Pode-se observar alguns valores distantes do restante como aqueles que tem menos de 20 anos de tempo de emprego e possuem valores de renda acima de 50000 e também o valor acima de 80000 porém correpondente ao tempo de emprego de mais de 40 anos.

# %% [markdown]
# 3) Na sua aopinião, há outliers na variável renda?

# %%
#Verifica a natureza do gráfico da variável renda
sns.histplot(data = previsao_renda_semna['renda'],
             kde = True)
# Out:
# <Axes: xlabel='renda', ylabel='Count'>

# %% [markdown]
# Como observado nos gráficos acima, nota-se que há outliers, porém ao analisar o gráfico para renda separadamente, percebe-se que ocorrem devido a característica de descrescimento logarítimico da variável renda.

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
#Cálculo log para a variável renda
previsao_renda_log = previsao_renda_semna.copy()
previsao_renda_log['log_renda'] = np.log(previsao_renda_semna['renda'])
previsao_renda_log.head()
# Out:
#      data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01    F             False             True           1
# 1  2015-01-01    M              True             True           0
# 2  2015-01-01    M              True             True           2
# 3  2015-01-01    F              True            False           0
# 4  2015-01-01    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda  log_renda
# 0       3.575342                    3.0  False  3369.24   8.122442
# ...

# %%
#Seleção variáveis numéricas quantitativas
var_quantitativo = list(previsao_renda_log.select_dtypes('number'))
previsao_renda_log[var_quantitativo].head()
# Out:
#    qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda  log_renda
# 0           1     36       3.575342                    3.0  3369.24   8.122442
# 1           0     42       0.860274                    2.0  6096.14   8.715411
# 2           2     31       8.065753                    4.0  5658.98   8.640999
# 3           0     50       1.208219                    2.0  7246.69   8.888300
# 4           0     52      13.873973                    2.0  4017.37   8.298383

# %%
#Estrutura de correlação variáveis numéricas
previsao_renda_log[var_quantitativo].corr()
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.289012      -0.074250
# idade                   -0.289012  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.908703 -0.257281      -0.065748
# renda                   -0.016189  0.151364       0.394235
# log_renda               -0.005300  0.145638       0.379556
#
#                        qt_pessoas_residencia     renda  log_renda
# qtd_filhos                          0.908703 -0.016189  -0.005300
# idade                              -0.257281  0.151364   0.145638
# tempo_emprego                      -0.065748  0.394235   0.379556
# qt_pessoas_residencia               1.000000 -0.004865   0.008412
# renda                              -0.004865  1.000000   0.836656
# log_renda                           0.008412  0.836656   1.000000

# %%
#Matriz de dispersão para as variáveis numéricas
var_quantitativo = list(previsao_renda_log.select_dtypes('number'))

var_quantitativo.append('mau')

sns.pairplot(previsao_renda_log[var_quantitativo].sample(n=5000), hue='mau')

# %%
#Clustermap da estrutura de correlação
var_quantitativo = list(previsao_renda_log.select_dtypes('number'))

color = sns.diverging_palette(h_neg=125, 
                              h_pos=600, 
                              as_cmap=True, 
                              sep = 40, 
                              center = 'light')

sns.clustermap(previsao_renda_log[var_quantitativo].corr(),
               figsize=(8, 8), 
               center = 0, 
               cmap=color)

# %%
#Gráfico scatterplot do log da renda pelo tempo de emprego
sns.scatterplot(data=previsao_renda_log[var_quantitativo].sample(n=500),
                x='tempo_emprego', 
                y='log_renda')

plt.yticks(range(0,21, 2))
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
#Gráfico regplot do log da renda pelo tempo de emprego
sns.regplot(data=previsao_renda_log[var_quantitativo].sample(n=500),
            x='tempo_emprego', 
            y='log_renda')

plt.yticks(range(0,21, 2))
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %%
#Gráfico log da renda
sns.histplot(previsao_renda_log['log_renda'], 
             kde=True)

plt.title('Histograma da variável: log_renda')
plt.ylabel('Contagem')
# Out:
# Text(0, 0.5, 'Contagem')

# %% [markdown]
# Como a característica da variável renda era um gráfico com um descréscimo logarítmico, a aplicação do logaritmo fez com que a distribuição dos dados no gráfico ficasse muito mais uniforme, facilitando assim a análise.
